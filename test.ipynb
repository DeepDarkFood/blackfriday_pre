# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/BlackFriday.csv')

# %%
data['User_ID']=range(537577)
print(data)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0             0  P00069042      F   0-17          10             A
# 1             1  P00248942      F   0-17          10             A
# 2             2  P00087842      F   0-17          10             A
# 3             3  P00085442      F   0-17          10             A
# 4             4  P00285442      M    55+          16             C
# 5             5  P00193542      M  26-35          15             A
# 6             6  P00184942      M  46-50           7             B
# 7             7  P00346142      M  46-50           7             B
# 8             8   P0097242      M  46-50           7             B
# 9             9  P00274942      M  26-35          20             A
# 10           10  P00251242      M  26-35          20             A
# 11           11  P00014542      M  26-35          20             A
# 12           12  P00031342      M  26-35          20             A
# ...

# %%
city_data=data.set_index(['City_Category'])
print(city_data)
# Out:
#                User_ID Product_ID Gender    Age  Occupation  \
# City_Category
# A                    0  P00069042      F   0-17          10
# A                    1  P00248942      F   0-17          10
# A                    2  P00087842      F   0-17          10
# A                    3  P00085442      F   0-17          10
# C                    4  P00285442      M    55+          16
# A                    5  P00193542      M  26-35          15
# B                    6  P00184942      M  46-50           7
# B                    7  P00346142      M  46-50           7
# B                    8   P0097242      M  46-50           7
# A                    9  P00274942      M  26-35          20
# A                   10  P00251242      M  26-35          20
# A                   11  P00014542      M  26-35          20
# A                   12  P00031342      M  26-35          20
# A                   13  P00145042      M  26-35          20
# ...

# %%
city_data = city_data['Purchase']
print(city_data)
# Out:
# City_Category
# A     8370
# A    15200
# A     1422
# A     1057
# C     7969
# A    15227
# B    19215
# B    15854
# B    15686
# A     7871
# A     5254
# A     3957
# A     6073
# A    15665
# A     5378
# A     2079
# A    13055
# A     8851
# B    11788
# C    19614
# C     8584
# C     9872
# C     9743
# C     5982
# C    11927
# C    16662
# C     5887
# C     6973
# C     5391
# B    16352
#      ...
# C    11543
# B    20924
# B    13082
# C    11658
# C     6863
# C    16415
# C    18526
# C     7099
# C      578
# A     2183
# A    12724
# A     7796
# A     7770
# A     5940
# A     7834
# A    11508
# A     6074
# A     7084
# A     7934
# A     5350
# A     1994
# A     5930
# A     7042
# A    15491
# C    11852
# C    11664
# C    19196
# C     8043
# C     7172
# C     6875
# Name: Purchase, Length: 537577, dtype: int64

# %%
pd.DataFrame(city_data).groupby(level=0).describe()
# Out:
#                Purchase                                                   \
#                   count         mean          std    min     25%     50%
# City_Category
# A              144638.0  8958.011014  4866.896600  185.0  5419.0  7941.0
# B              226493.0  9198.657848  4927.062965  185.0  5477.0  8015.0
# C              166446.0  9844.441855  5109.472100  186.0  6094.0  8618.0
#
#
#                     75%      max
# City_Category
# A              11801.75  23961.0
# B              12000.00  23960.0
# C              13268.00  23961.0

# %%
city_data=city_data.reset_index()

# %%
plt.boxplot(city_data[city_data['City_Category']=='A']['Purchase'],showfliers=False)
plt.boxplot(city_data[city_data['City_Category']=='B']['Purchase'],showfliers=False)
plt.boxplot(city_data[city_data['City_Category']=='C']['Purchase'],showfliers=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fa3d0f6940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fa3bdc4438>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fa3d0f6518>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fa3bdc4978>],
#  'fliers': [],
#  'means': []}
